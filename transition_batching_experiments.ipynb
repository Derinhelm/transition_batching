# %% [markdown]
# <a href="https://colab.research.google.com/github/Derinhelm/transition_batching/blob/main/transition_batching_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Derinhelm/transition_batching.git
# Out:
# Cloning into 'transition_batching'...
# remote: Enumerating objects: 7475, done.
# remote: Counting objects: 100% (1414/1414), done.
# remote: Compressing objects: 100% (1346/1346), done.
# remote: Total 7475 (delta 76), reused 107 (delta 63), pack-reused 6061 (from 1)
# Receiving objects: 100% (7475/7475), 61.16 MiB | 12.57 MiB/s, done.
# Resolving deltas: 100% (1063/1063), done.
# Updating files: 100% (14273/14273), done.

# %%
# !mv /content/transition_batching/venv /content/venv
# !mv /content/transition_batching/uuparser-master /content/uuparser-master

# %%
# !source /content/venv/bin/activate; which python3
# Out:
# /content/venv/bin/python3

# %%
# !source /content/venv/bin/activate && python3 -c "import dynet"
# Out:
# [dynet] random seed: 3845887684
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.

# %%
# !source /content/venv/bin/activate && pip install h5py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 33.1 MB/s eta 0:00:00
# ...

# %%
# !source /content/venv/bin/activate; pip install loguru
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 KB 1.4 MB/s eta 0:00:00
# ...

# %%
# !source /content/venv/bin/activate; pip install tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 2.1 MB/s eta 0:00:00
# ...

# %%
#!source /content/venv/bin/activate; pip install uuparser

# %%
# !wget -m https://github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-train.conllu
# !wget -m https://github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-dev.conllu
# !wget -m https://github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-test.conllu
# Out:
# --2024-12-13 21:15:02--  https://github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-train.conllu
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Derinhelm/graph_syntax_parsing/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-train.conllu [following]
# --2024-12-13 21:15:03--  https://raw.githubusercontent.com/Derinhelm/graph_syntax_parsing/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-train.conllu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3150 (3.1K) [text/plain]
# ...

# %%
# !mkdir /content/UD_Russian-SynTagRus/
# !mv /content/github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-train.conllu /content/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# !mv /content/github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-dev.conllu /content/UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu
# !mv /content/github.com/Derinhelm/graph_syntax_parsing/raw/refs/heads/main/UD_Russian-SynTagRus-small/ru_syntagrus-ud-test.conllu /content/UD_Russian-SynTagRus/ru_syntagrus-ud-test.conllu

# %%
# !rm -r /content/github.com

# %%
# !source /content/venv/bin/activate; PYTHONPATH=/content/uuparser-master python3 /content/uuparser-master/uuparser/parser.py --outdir /content/res --datadir /content --include "ru_syntagrus" --dynet-seed 123456789 --dynet-mem 10000
# Out:
# [uuparser] 2024-12-13T21:15:06 INFO: Creating output directory /content/res
# [uuparser] 2024-12-13T21:15:06 INFO: Creating language-specific output directory /content/res/ru_syntagrus
# [uuparser] 2024-12-13T21:15:06 INFO: Working with a transition-based parser
# [uuparser] 2024-12-13T21:15:06 INFO: Reading /content/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# [uuparser] 2024-12-13T21:15:06 INFO: Time: 0.0019s
# [uuparser] 2024-12-13T21:15:06 INFO: Saving params to /content/res/ru_syntagrus/params.pickle
# [dynet] random seed: 123456789
# [dynet] allocating memory: 10000MB
# [dynet] memory allocation done.
# [uuparser] 2024-12-13T21:15:15 INFO: No word external embeddings found: all vectors initialised randomly
# [uuparser] 2024-12-13T21:15:15 INFO: No character external embeddings found: all vectors initialised randomly
# [uuparser] 2024-12-13T21:15:15 INFO: Starting epoch 1
# ...

# %%
#!source /content/venv/bin/activate; uuparser --outdir /content/res --datadir /content --include "ru_syntagrus" --dynet-seed 123456789 --dynet-mem 10000
